# %% [markdown]
# <a href="https://colab.research.google.com/github/GOPALNAMDEV/My_Python_code/blob/main/Matplotlib/Matplotlib_day3_pie_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

plt.style.use('fivethirtyeight')

slices = ['60', '40']
labels = ['60s', '40s']
explode = [0, 0.1]

plt.pie(slices, labels = labels, explode= explode, shadow=True,
        autopct='%1.1f%%', startangle=90,
        wedgeprops ={'edgecolor':'black'})


plt.title('My Awsome Pie chart')
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt

plt.style.use('fivethirtyeight')

#if i want to represent the numbers in pie chart then it will be asign as "slices"

# slices = [59219, 55466, 47544, 36443, 35917, 31991, 27097,
#           23030, 20524, 18523, 18017, 7920, 7331, 7201, 5833]
# labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell',
#           'C#', 'PHP','C++',  'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly']

slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.1, 0]


#slices is the data , labels is the name, explode is the space between the cutted part or the part which i want to seperate like a piece of cake,
# shadow to add shadow, startangle to set position and the autopct creates the percentage of data inside the piechart

plt.pie(slices, labels = labels, explode= explode, shadow=True,
        autopct='%1.1f%%', startangle=90,
        wedgeprops ={'edgecolor':'black'})


plt.title('My Awsome Pie chart')
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt

plt.style.use('seaborn-v0_8-muted')

#if i want to represent the numbers in pie chart then it will be asign as "slices"

# slices = [59219, 55466, 47544, 36443, 35917, 31991, 27097,
#           23030, 20524, 18523, 18017, 7920, 7331, 7201, 5833]
# labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell',
#           'C#', 'PHP','C++',  'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly']

slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.1, 0]
colors = ['#8ecae6', '#219ebc', '#023047', '#ffb703', '#fb8500']



#slices is the data , labels is the name, explode is the space between the cutted part or the part which i want to seperate like a piece of cake,
# shadow to add shadow, startangle to set position and the autopct creates the percentage of data inside the piechart

plt.pie(slices, labels = labels, explode= explode, shadow=True,
        autopct='%1.1f%%', startangle=90,
        wedgeprops={'edgecolor': 'dimgray', 'linewidth': 1.5})


plt.title('My Awsome Pie chart')
plt.tight_layout()
plt.show()
