# %% [markdown]
# <a href="https://colab.research.google.com/github/GOPALNAMDEV/My_Python_code/blob/main/Matplotlib/Matplotlib_day5_Plot_Fills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import pandas as pd

data = pd.read_csv('/content/data (1).csv')
print(df.columns)

Age  = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']
color = 'r','g','b','k'
linestyle = '--','--','--','--'
label = 'All_Devs', 'Python','JavaScript'
plt.plot(Age, dev_salaries,color= '#444444',linestyle = '--',label='label')
plt.plot(Age, py_salaries,color= '#5a7d9a',label='label')
plt.plot(Age, js_salaries,color= '#adad3b',label='label')

#in this fill_between is used to fill the inner space of the line graph

plt.fill_between(Age, py_salaries)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Index(['Age', 'All_Devs', 'Python', 'JavaScript'], dtype='object')

# %%
from matplotlib import pyplot as plt
import pandas as pd

data = pd.read_csv('/content/data (1).csv')
print(df.columns)

Age  = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']
color = 'r','g','b','k'
linestyle = '--','--','--','--'
label = 'All_Devs', 'Python','JavaScript'
plt.plot(Age, dev_salaries,color= '#444444',linestyle = '--',label='label')
plt.plot(Age, py_salaries,color= '#5a7d9a',label='label')
plt.plot(Age, js_salaries,color= '#adad3b',label='label')

#in this fill_between is used to fill the inner space of the line graph

plt.fill_between(Age, py_salaries, alpha =0.25)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Index(['Age', 'All_Devs', 'Python', 'JavaScript'], dtype='object')

# %%
from matplotlib import pyplot as plt
import pandas as pd

data = pd.read_csv('/content/data (1).csv')
print(df.columns)

Age  = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']
color = 'r','g','b','k'
linestyle = '--','--','--','--'
label = 'All_Devs', 'Python','JavaScript'
plt.plot(Age, dev_salaries,color= '#444444',linestyle = '--',label='label')
plt.plot(Age, py_salaries,color= '#5a7d9a',label='label')
plt.plot(Age, js_salaries,color= '#adad3b',label='label')


#here i used overall_median which will fill the area in a particular interval if the data is smaller than this
#this will fill lower portion externally and if large fill the higher portion internally
overall_median = 57287

#in this fill_between is used to fill the inner space of the line graph
plt.fill_between(Age, py_salaries, overall_median, alpha =0.25) #alpha is used for the managing the solidity
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Index(['Age', 'All_Devs', 'Python', 'JavaScript'], dtype='object')

# %%
from matplotlib import pyplot as plt
import pandas as pd

data = pd.read_csv('/content/data (1).csv')
print(df.columns)

Age  = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']
color = 'r','g','b','k'
linestyle = '--','--','--','--'
label = 'All_Devs', 'Python','JavaScript'
plt.plot(Age, dev_salaries,color= '#444444',linestyle = '--',label='label')
plt.plot(Age, py_salaries,color= '#5a7d9a',label='label')
plt.plot(Age, js_salaries,color= '#adad3b',label='label')


#here i used overall_median which will fill the area in a particular interval if the data is smaller than this
#this will fill lower portion externally and if large fill the higher portion internally
overall_median = 57287

#in this fill_between is used to fill the inner space of the line graph
plt.fill_between(Age, py_salaries, overall_median,
                 where= (py_salaries > overall_median), interpolate =True,alpha =0.25) #alpha is used for the managing the solidity
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Index(['Age', 'All_Devs', 'Python', 'JavaScript'], dtype='object')

# %%
from matplotlib import pyplot as plt
import pandas as pd

data = pd.read_csv('/content/data (1).csv')
print(df.columns)

Age  = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']
color = 'r','g','b','k'
linestyle = '--','--','--','--'
label = 'All_Devs', 'Python','JavaScript'
plt.plot(Age, dev_salaries,color= '#444444',linestyle = '--',label='label')
plt.plot(Age, py_salaries,color= '#5a7d9a',label='label')
plt.plot(Age, js_salaries,color= '#adad3b',label='label')


overall_median = 57287

plt.fill_between(Age, py_salaries, overall_median,
                 where= (py_salaries > overall_median), interpolate =True,alpha =0.25)
plt.fill_between(Age, py_salaries, overall_median,
                 where= (py_salaries <= overall_median), interpolate =True,alpha =0.25)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Index(['Age', 'All_Devs', 'Python', 'JavaScript'], dtype='object')

# %%
from matplotlib import pyplot as plt
import pandas as pd

data = pd.read_csv('/content/data (1).csv')
print(df.columns)

Age  = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']
color = 'r','g','b','k'
linestyle = '--','--','--','--'
label = 'All_Devs', 'Python','JavaScript'
plt.plot(Age, dev_salaries,color= '#444444',linestyle = '--',label='label')
plt.plot(Age, py_salaries,color= '#5a7d9a',label='label')
plt.plot(Age, js_salaries,color= '#adad3b',label='label')


overall_median = 57287

plt.fill_between(Age, py_salaries, overall_median,
                 where= (py_salaries > overall_median), color ='green', interpolate =True,alpha =0.25)
plt.fill_between(Age, py_salaries, overall_median,
                 where= (py_salaries <= overall_median), color='red', interpolate =True,alpha =0.25)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Index(['Age', 'All_Devs', 'Python', 'JavaScript'], dtype='object')

# %%
from matplotlib import pyplot as plt
import pandas as pd

data = pd.read_csv('/content/data (1).csv')
print(df.columns)

Age  = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']
color = 'r','g','b','k'
linestyle = '--','--','--','--'
plt.plot(Age, dev_salaries,color= '#444444',linestyle = '--',label='All_Devs')
plt.plot(Age, py_salaries,color= '#5a7d9a',label='Python')
plt.plot(Age, js_salaries,color= '#adad3b',label='JavaScript')


overall_median = 57287

plt.fill_between(Age, py_salaries, dev_salaries,
                 where= (py_salaries > dev_salaries), interpolate =True,alpha =0.25, label='Above Average')
plt.fill_between(Age, py_salaries, dev_salaries,
                 where= (py_salaries <= dev_salaries), color='red', interpolate =True,alpha =0.25, label ='Below Average')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# Index(['Age', 'All_Devs', 'Python', 'JavaScript'], dtype='object')
