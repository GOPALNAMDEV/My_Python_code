# %% [markdown]
# <a href="https://colab.research.google.com/github/GOPALNAMDEV/My_Python_code/blob/main/machine_learning/02_Boston_Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Housing Data***

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
housing = pd.read_csv('/content/HousingData.csv')

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'CRIM'}>, <Axes: title={'center': 'ZN'}>,
#         <Axes: title={'center': 'INDUS'}>,
#         <Axes: title={'center': 'CHAS'}>],
#        [<Axes: title={'center': 'NOX'}>, <Axes: title={'center': 'RM'}>,
#         <Axes: title={'center': 'AGE'}>, <Axes: title={'center': 'DIS'}>],
#        [<Axes: title={'center': 'RAD'}>, <Axes: title={'center': 'TAX'}>,
#         <Axes: title={'center': 'PTRATIO'}>,
#         <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'LSTAT'}>,
#         <Axes: title={'center': 'MEDV'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# # **Train-test-split**

# %%
# def split_train_test(data, test_ratio):
#   np.random.seed(42) #this will fix the randomizer function which avoids overfitting
#   suffled = np.random.permutation(len(data))   #can cause overfitting because if the program run longer time it will give the chance to every element to try once in mocel which can cause the errror 0% but for only our seeded data
#   test_data_size = int(len(data) * test_ratio)
#   test_indice = suffled[:test_data_size]
#   train_indice = suffled[test_data_size:]
#   return data.iloc[train_indice], data.iloc[test_indice]

# %%
# train_set, test_set = split_train_test(housing, 0.2)

# %%
# housing=train_set.copy()

# %% [markdown]
# ### ***train_set , test_set = train_test_split(dataset, test_size=0.2, random_state=42)***

# %%
train_set , test_set = train_test_split(housing, test_size=0.2, random_state=42)
print(f"Rows in test data set: {len(test_set)}\n Rows in train set: {len(train_set)}")
# Out:
# Rows in test data set: 102
#  Rows in train set: 404

# %%
from sklearn.model_selection import StratifiedShuffleSplit
# Drop rows with NaN in CHAS
housing = housing.dropna(subset=['CHAS'])

from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing['CHAS']):
    strat_train_set = housing.iloc[train_index]
    strat_test_set = housing.iloc[test_index]

# %%
strat_test_set['CHAS'].value_counts()     #91/7 =13.0
# Out:
# CHAS
# 0.0    91
# 1.0     7
# Name: count, dtype: int64

# %%
strat_train_set['CHAS'].value_counts()   #361/27 = 13.37037037037037 using almost same ratio as test_set this is the functioning of StratifiedShuffleSplit
# Out:
# CHAS
# 0.0    361
# 1.0     27
# Name: count, dtype: int64

# %%
housing= strat_train_set.copy()

# %% [markdown]
# ## looking for **coorelations**

# %%
corr_matrix = housing.corr()
corr_matrix['MEDV'].sort_values(ascending = False)
# Out:
# MEDV       1.000000
# RM         0.683127
# ZN         0.360756
# B          0.356262
# DIS        0.261544
# CHAS       0.137131
# RAD       -0.376848
# CRIM      -0.389955
# AGE       -0.393214
# NOX       -0.424128
# TAX       -0.453324
# PTRATIO   -0.478686
# INDUS     -0.481411
# LSTAT     -0.743966
# Name: MEDV, dtype: float64

# %%
attributes = ['MEDV', 'RM', 'ZN', 'LSTAT']
pd.plotting.scatter_matrix(housing[attributes], figsize=(12,8))
# Out:
# array([[<Axes: xlabel='MEDV', ylabel='MEDV'>,
#         <Axes: xlabel='RM', ylabel='MEDV'>,
#         <Axes: xlabel='ZN', ylabel='MEDV'>,
#         <Axes: xlabel='LSTAT', ylabel='MEDV'>],
#        [<Axes: xlabel='MEDV', ylabel='RM'>,
#         <Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='ZN', ylabel='RM'>,
#         <Axes: xlabel='LSTAT', ylabel='RM'>],
#        [<Axes: xlabel='MEDV', ylabel='ZN'>,
#         <Axes: xlabel='RM', ylabel='ZN'>,
#         <Axes: xlabel='ZN', ylabel='ZN'>,
#         <Axes: xlabel='LSTAT', ylabel='ZN'>],
#        [<Axes: xlabel='MEDV', ylabel='LSTAT'>,
#         <Axes: xlabel='RM', ylabel='LSTAT'>,
#         <Axes: xlabel='ZN', ylabel='LSTAT'>,
#         <Axes: xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing = strat_train_set.drop('MEDV', axis =1)
housing_labels = strat_train_set['MEDV'].copy()

# %% [markdown]
# # **Handling missing values**

# %%
# 1.   Get rid of missing data points
# 2.   Get rid of the whole attribute
# 3.   set the value to same (0, mean, median)

# %%
# a = housing.dropna(subset=['RM','LSTAT','AGE','CRIM','ZN','INDUS','CHAS']) #option-1
# a.shape

# %%
# housing.drop('RM' , axis=1).shape #option-2
# #now here is no RM column

# %%
median = housing['RM'].median() #option-3 compute median and fill in place of na

# %%
housing["RM"].fillna(median)
# Out:
# 273    7.691
# 184    5.604
# 431    6.833
# 26     5.813
# 289    6.565
#        ...
# 379    6.223
# 183    6.563
# 427    6.202
# 405    5.683
# 167    5.877
# Name: RM, Length: 388, dtype: float64

# %%
housing.shape
# Out:
# (388, 13)

# %%
housing.describe()  # before starting filling missing attributes
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  375.000000  375.000000  374.000000  388.000000  388.000000  388.000000
# mean     3.800107   10.218667   11.303583    0.069588    0.560847    6.298647
# std      9.339069   21.937232    6.745910    0.254779    0.118430    0.693680
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.090665    0.000000    5.222500    0.000000    0.458000    5.877750
# 50%      0.299160    0.000000    9.900000    0.000000    0.538000    6.211500
# 75%      3.685665    0.000000   18.100000    0.000000    0.631000    6.631250
# max     88.976200   95.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  372.000000  388.000000  388.000000  388.000000  388.000000  388.000000
# mean    69.532527    3.707329    9.693299  409.337629   18.490979  353.648943
# std     28.015704    2.048942    8.773419  168.619296    2.186828   93.623514
# min      2.900000    1.129600    1.000000  187.000000   12.600000    2.520000
# 25%     45.800000    2.097050    4.000000  279.000000   17.400000  374.335000
# 50%     79.450000    3.122200    5.000000  330.000000   19.100000  390.670000
# 75%     94.425000    4.978850   24.000000  666.000000   20.200000  395.810000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  371.000000
# mean    12.830755
# std      7.080449
# min      1.980000
# 25%      7.025000
# 50%     11.720000
# 75%     17.100000
# max     36.980000

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_.shape
# Out:
# (13,)

# %%
X= imputer.transform(housing)

# %%
housing_tr = pd.DataFrame(X, columns=housing.columns)

# %%
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  388.000000  388.000000  388.000000  388.000000  388.000000  388.000000
# mean     3.682807    9.876289   11.252938    0.069588    0.560847    6.298647
# std      9.202518   21.644089    6.627951    0.254779    0.118430    0.693680
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.092300    0.000000    5.860000    0.000000    0.458000    5.877750
# 50%      0.299160    0.000000    9.900000    0.000000    0.538000    6.211500
# 75%      3.543427    0.000000   18.100000    0.000000    0.631000    6.631250
# max     88.976200   95.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  388.000000  388.000000  388.000000  388.000000  388.000000  388.000000
# mean    69.941495    3.707329    9.693299  409.337629   18.490979  353.648943
# std     27.501429    2.048942    8.773419  168.619296    2.186828   93.623514
# min      2.900000    1.129600    1.000000  187.000000   12.600000    2.520000
# 25%     47.200000    2.097050    4.000000  279.000000   17.400000  374.335000
# 50%     79.450000    3.122200    5.000000  330.000000   19.100000  390.670000
# 75%     94.100000    4.978850   24.000000  666.000000   20.200000  395.810000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  388.000000
# mean    12.782088
# std      6.926930
# min      1.980000
# 25%      7.250000
# 50%     11.720000
# 75%     16.672500
# max     36.980000

# %% [markdown]
# # **Scikit-learn Design**

# %% [markdown]
# *Primarily, three types of objects*
#
#
# 1.   *Estimators* - it estimates some parameter based on a datase. EG. imputer
# It has a fit method and transform method. Fit method - Fits the dataset and calculates internal parameters
#
# 2.   *Transformer* - tranform method takes input and written output based on the learning from *fit()*. it also has a convinience function called *fit_transform()* which fits and then transforms.
#
# 3.   *Predictors* - LinearRegression model is a example of predictor. *fit()* and *predict()* are two common functions. it also gives *score()* function which will evaluate the predictions.

# %% [markdown]
# # **Feature Scaling**

# %% [markdown]
# Primarily, two types of feature scaling methods:
#
# 1. Min-max scaling (Normalization)
# (Value-min)/(max-min)
# Sklearn provides a class called MinMaxScaler for this
#
# 2. Standardization
#    (value - mean)/std
# Sklearn provides a class called StandardScaler for this

# %% [markdown]
# # **Creating a pipeline**

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    # add as many as you want in pipelining
    ('std_scaler', StandardScaler()),
])

# %%
housing_num_tr = my_pipeline.fit_transform(housing)

# %%
housing_num_tr.shape
# Out:
# (388, 13)

# %% [markdown]
# # **Selecting a desired model**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
# model = LinearRegression()
# model = DecisionTreeRegressor()
model.fit(housing_num_tr,housing_labels)
# Out:
# RandomForestRegressor()

# %%
some_data = housing.iloc[:5]

# %%
some_labels = housing_labels.iloc[:5]

# %%
prepared_data = my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([37.62 , 25.931, 16.108, 17.012, 24.853])

# %%
list(some_labels)
# Out:
# [35.2, 26.4, 14.1, 16.6, 24.8]

# %% [markdown]
# # **Evaluating Model**

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = model.predict(housing_num_tr)
mse = mean_squared_error(housing_labels, housing_predictions)
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(1.3289206233616344)

# %% [markdown]
# # **Using better evaluation technique - Cross Validation**

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, housing_num_tr, housing_labels, scoring='neg_mean_squared_error', cv=10)
rmse_scores = np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([3.2368782 , 2.36661723, 2.40725608, 3.12803896, 2.94251579,
#        4.79316068, 4.62007816, 3.30765491, 3.19020865, 3.07082432])

# %%
def print_scores(scores):
  print("\nScores: ", scores)
  print("\nMean: ", scores.mean())
  print("\nStandard Deviation: ", scores.std())

# %%
print_scores(rmse_scores)
# Out:
# Scores:  [3.2368782  2.36661723 2.40725608 3.12803896 2.94251579 4.79316068
#  4.62007816 3.30765491 3.19020865 3.07082432]
#
# Mean:  3.3063232953477595
#
# Standard Deviation:  0.7658925883285843

# %%
from joblib import dump, load
dump(model, 'Boston.joblib')
# Out:
# ['Boston.joblib']

# %%
X_test =strat_test_set.drop("MEDV", axis=1)
Y_test = strat_test_set["MEDV"].copy()
X_test_prepared = my_pipeline.transform(X_test)
final_predictions = model.predict(X_test_prepared)
final_mse = mean_squared_error(Y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
print(final_predictions, list(Y_test))
# Out:
# [21.799 23.271 20.776 23.05  19.765 22.042 26.598 43.586 19.635 15.562
#  47.094 31.309 28.11  19.729 21.174 22.764 16.104 43.647 45.764 22.241
#  21.095 44.564 19.926 21.994 15.427 12.322 20.275 43.688 33.881 18.519
#  22.8   19.919 23.139 45.078 21.125 34.825 31.988 18.316 26.251 17.562
#  31.191 32.796 33.658 23.579 13.379 23.448 21.301 21.095 13.132 22.424
#  24.273 20.022 23.6   20.465 18.086 36.114  6.971 21.946 32.856 32.346
#  16.909 25.003 23.418 14.671 22.597 17.337 19.072 24.411  9.233 27.087
#  21.667 40.578 23.676 29.283 11.485 21.148 14.585 25.83  26.443 15.944
#   6.896 21.699 20.88  14.742 23.683 14.632 28.89  14.736 23.221 20.201
#  24.414 13.272 16.255  8.682 14.17  19.434 19.232 24.514] [23.4, 22.0, 17.5, 24.7, 23.1, 25.2, 28.4, 42.3, 18.9, 15.2, 48.5, 24.8, 23.9, 16.6, 20.1, 22.9, 14.2, 46.0, 50.0, 11.9, 22.8, 50.0, 22.6, 23.0, 23.2, 13.3, 21.8, 50.0, 32.9, 19.4, 23.9, 19.3, 23.3, 50.0, 21.2, 36.5, 28.2, 21.7, 25.0, 15.7, 32.4, 31.6, 31.7, 22.3, 17.9, 21.6, 23.1, 18.6, 17.2, 20.6, 23.7, 18.7, 23.9, 23.0, 19.5, 33.4, 10.5, 19.4, 32.0, 34.9, 15.6, 24.3, 21.6, 8.1, 24.1, 13.8, 21.4, 36.2, 9.7, 25.1, 21.0, 50.0, 23.2, 29.9, 13.8, 16.1, 19.0, 22.0, 27.1, 11.7, 5.0, 19.8, 21.7, 14.5, 23.6, 7.0, 31.5, 17.8, 21.4, 17.2, 22.2, 9.6, 18.1, 7.2, 12.5, 23.1, 17.6, 22.9]

# %%
final_rmse
# Out:
# np.float64(3.331903800948566)

# %%
model = load('Boston.joblib')
feature = np.array([[-0.37657036,  0.46833955, -0.6485384 ,  3.6565517 , -0.81881682,
        2.00979003, -0.66050817,  0.3221284 , -0.76389163, -1.10650574,
        0.04991767,  0.39700482, -0.89651483]])
model.predict(feature)
# Out:
# array([37.62])
